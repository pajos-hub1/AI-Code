# %% [markdown]
# 1. Write this code and tell me what it prints.
# name = "Your Name"
# age = 19
# print(f"My name is {name} and I am {age} years old.")

# %%
name = "Joseph Adeoye"
age = 19

print(f'My name is {name} and I am {age} years old')
# Out:
# My name is Joseph Adeoye and I am 19 years old

# %% [markdown]
# 2. Tell me the Data type that each belongs.
# - a = "100" - Strings
# - b = 100 - Integer
# - c = 100.0 - Float
# - d = False - Boolean

# %% [markdown]
# 3. Fix this so it prints 15 (not “105”)
# x = "10"
# y = "5"
# print(x + y)

# %%
x = int("10")
y = int("5")
print(x + y)
# Out:
# 15

# %% [markdown]
# 4. A user enters 1.75 for height. Write code to:
# - i. Collect with input.
# - ii. Convert it properly.
# - iii. Add 2.5.
# - iv. Print result

# %%
height = float(input('Enter your height: '))
result = height + 2.5
print(f'Your new height is {result}')
# Out:
# Enter your height: 1.75
# Your new height is 4.25

# %% [markdown]
# 5. Print the data types of the followings.
# - action = “Run”
# - distance = 100
# - time = 9.5
# - is_complete = True

# %%
action = "Run"
print(type(action))
distance = 100
print(type(distance))
time = 9.5
print(type(time))
is_complete = True
print(type(is_complete))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
